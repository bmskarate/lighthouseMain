# %%
import pandas as pd
day_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
levels = [60, 55, 67, 45, 38]

# %%
plotdata = pd.DataFrame({"pollution": levels},
                       index=day_of_week)
plotdata.plot(kind="bar")
# Out:
# <AxesSubplot:>
