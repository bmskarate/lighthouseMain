# %% [markdown]
# ## Plotly Assignment
#
# **Note**: For some of you, plotly go does not display at all in Jupyter Labs. It is a known bug with plotly. If you are using Jupyter Labs for this assignment and the plots are not showing, please switch to Jupyter Notebooks or Google Collab to complete this exercise.

# %%
# import plotly graph objects
import plotly.graph_objs as go
import plotly.express as px

# import pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ### Task 1: Create a scatterplot with a 1000 random data points.
#
# - x-axis values should come from a normal distribution using np.random.randn(1000)
#
# - y-axis values should come from a uniform distribution over [0,1) using np.random.rand(1000)

# %%
# obtain the x and y values:
random_x = np.random.randint(1,101,1000)
random_y = np.random.randint(1,101,1000)

# %%
# define a data variable
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
)]

# %%
# define the layout, include a title and axis labels
layout = go.Layout(
    title = 'lots of dots', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# Create a fig from the data and layout. Then plot the fig
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="76516c9d-1bfd-4c0c-baf0-70dca850387b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76516c9d-1bfd-4c0c-baf0-70dca850387b")) {                    Plotly.newPlot(                        "76516c9d-1bfd-4c0c-baf0-70dca850387b",                        [{"mode":"markers","type":"scatter","x":[54,54,94,82,21,70,13,78,72,60,34,75,37,59,33,87,50,77,5,77,68,42,65,45,29,44,96,32,81,32,15,23,12,73,38,52,89,87,64,65,58,72,76,30,83,47,21,16,39,88,67,35,78,90,23,37,21,88,29,19,45,31,47,71,78,99,50,74,4,37,74,23,11,17,36,21,7,92,15,53,16,41,70,21,98,77,86,28,37,32,11,61,68,46,29,97,44,96,14,82,25,76,36,1,19,50,17,1,74,9,2,89,48,91,21,19,86,83,95,64,51,35,72,22,30,60,89,34,97,53,10,11,80,32,42,100,89,86,86,11,92,62,10,74,28,70,51,39,26,64,4,70,70,34,7,16,25,94,74,59,38,100,50,99,89,35,69,13,91,46,74,53,87,98,56,55,86,8,23,18,52,62,58,51,43,22,42,80,92,70,11,72,64,1,2,25,14,48,62,24,5,15,75,48,12,85,32,6,51,68,21,69,48,69,87,70,52,6,49,80,4,27,61,57,25,69,66,76,34,64,72,22,38,43,61,9,80,32,3,21,22,32,19,65,64,2,35,70,47,58,64,82,65,92,18,20,14,85,97,58,60,53,28,95,78,4,27,26,63,49,99,30,88,98,12,38,62,24,66,24,87,45,8,9,98,94,81,55,25,22,40,37,2,37,33,79,86,17,77,26,67,62,21,73,69,59,59,70,51,87,86,69,100,62,4,19,54,30,53,77,81,13,97,87,25,6,89,57,38,20,31,5,18,4,45,21,55,75,11,41,74,75,26,93,9,6,12,76,53,68,24,55,33,66,61,38,42,55,53,95,75,18,79,89,92,91,88,8,74,72,5,28,90,85,64,66,45,77,24,62,57,17,61,77,70,67,76,88,58,4,46,42,92,34,95,46,11,87,52,78,51,13,32,67,91,74,34,58,100,75,30,30,53,28,48,18,75,12,46,15,29,31,64,53,37,46,100,94,75,77,91,90,92,70,62,82,17,98,51,67,5,85,87,65,75,39,93,14,63,55,80,64,45,69,28,38,70,45,84,72,58,22,40,93,7,94,43,54,64,13,59,39,68,12,4,80,40,48,65,91,87,10,86,67,32,33,39,37,100,43,40,14,68,90,
://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv').set_index("Question")
df
# Out:
#             Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# Question 1            0.45            0.25     0.10               0.12
# Question 2            0.12            0.07     0.48               0.18
# Question 3            0.05            0.22     0.19               0.23
#
#             Strongly Disagree
# Question 1               0.08
# Question 2               0.15
# Question 3               0.31

# %% [markdown]
# # Make the index a column!

# %%
# create traces using a list comprehension:
f = "https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv"
df = pd.read_csv(f).rename(columns={"Unnamed: 0":"Question"}).set_index("Question")
df.head()
# Out:
#             Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# Question
# Question 1            0.45            0.25     0.10               0.12
# Question 2            0.12            0.07     0.48               0.18
# Question 3            0.05            0.22     0.19               0.23
#
#             Strongly Disagree
# Question
# Question 1               0.08
# Question 2               0.15
# Question 3               0.31

# %%
px.bar(df)
# Out:
# <div>                            <div id="571761c2-1333-45d5-99d8-e1071ef250c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("571761c2-1333-45d5-99d8-e1071ef250c3")) {                    Plotly.newPlot(                        "571761c2-1333-45d5-99d8-e1071ef250c3",                        [{"alignmentgroup":"True","hovertemplate":"variable=Strongly Agree<br>Question=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Strongly Agree","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Strongly Agree","offsetgroup":"Strongly Agree","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Question 1","Question 2","Question 3"],"xaxis":"x","y":[0.45,0.12,0.05],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=Somewhat Agree<br>Question=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Somewhat Agree","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Somewhat Agree","offsetgroup":"Somewhat Agree","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Question 1","Question 2","Question 3"],"xaxis":"x","y":[0.25,0.07,0.22],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=Neutral<br>Question=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Neutral","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Question 1","Question 2","Question 3"],"xaxis":"x","y":[0.1,0.48,0.19],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=Somewhat Disagree<br>Question=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Somewhat Disagree","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Somewhat Disagree","offsetgroup":"Somewhat Disagree","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Question 1","Question 2","Question 3"],"xaxis":"x","y":[0.12,0.18,0.23],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"variable=Strongly Disagree<br>Question=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Strongly Disagree","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Strongly Disagree","offsetgroup":"Strongly Disagree","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Question 1","Question 2","Question 3"],"xaxis":"x","y":[0.08,0.15,0.31],"yaxis":"y"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %%
# create a layout, remember to set the barmode here

# %%
# create a fig from data & layout, and plot the fig.

# %% [markdown]
# -------------
# ### Task 3: Create a histogram that plots the `length` field from dataset below. Set the range from 0 to 1, with a bin size of 0.02.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')

# %%
df.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# create a data variable:
data = [
    # men
    go.Histogram(
    x=df[df['sex']==0]['length'],
    opacity=0.75,
    name='Male'
),
    # women
    go.Histogram(
    x=df[df['sex']==1]['length'],
    opacity=0.75,
    name='Female'
)]

# %%
# add a layout
layout = go.Layout(
    barmode='overlay',
    title="Length comparison by gender"
)

# %%
# create a fig from data & layout, and plot the fig
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="74b1c2b0-e206-48c6-8e7f-9165b9c8851d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74b1c2b0-e206-48c6-8e7f-9165b9c8851d")) {                    Plotly.newPlot(                        "74b1c2b0-e206-48c6-8e7f-9165b9c8851d",                        [{"name":"Male","opacity":0.75,"type":"histogram","x":[]},{"name":"Female","opacity":0.75,"type":"histogram","x":[]}],                        {"barmode":"overlay","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{" ...
#
# var gd = document.getElementById('74b1c2b0-e206-48c6-8e7f-9165b9c8851d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{

# %%
px.histogram(data_frame=df, x="sex", y="length")
# Out:
# <div>                            <div id="c9226ff5-6ad7-49e1-8378-562e6ce2121d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_18919/3083952566.py in <module>
# ----> 1 fig = px.histogram(df, x="sex", nbins=0.02)
#       2 fig.show()
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, title, template, width, height)
#     454     `orientation` is `'h'`).
#     455     """
# --> 456     return make_figure(
#     457         args=locals(),
#     458         constructor=go.Histogram,
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2040                 args, trace_spec, group, mapping_labels.copy(), sizeref
#    2041             )
# -> 2042             trace.update(patch)
#    2043             if fit_results is not None:
#    2044                 trendline_rows.append(mapping_labels.copy())
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    5082                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5083         else:
# -> 5084             BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#    5085             BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5086
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3919                 else:
#    3920                     # Assign non-compound value
# -> 3921                     plotly_obj[key] = val
#    3922
#    3923         elif isinstance(plotly_obj, tuple):
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4817                 # ### Handle simple property ###
#    4818                 else:
# -> 4819                     self._set_prop(prop, value)
#    4820             else:
#    4821                 # Make sure properties dict is initialized
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5161                 return
#    5162             else:
# -> 5163                 raise err
#    5164
#    5165         # val is None
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5156
#    5157         try:
# -> 5158             val = validator.validate_coerce(val)
#    5159         except ValueError as err:
#    5160             if self._skip_invalid:
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v)
#     935             if not isinstance(v, int):
#     936                 # don't let int() cast strings to ints
# --> 937                 self.raise_invalid_val(v)
#     938
#     939             # Check min/max
#
# ~/opt/anaconda3/envs/plot/lib/python3.9/site-packages/_plotly_utils/basevalidators.py in raise_invalid_val(self, v, inds)
#     288                 name += "[" + str(i) + "]"
#     289
# --> 290         raise ValueError(
#     291             """
#     292     Invalid value of type {typ} received for the '{name}' property of {pname}
#
# ValueError:
#     Invalid value of type 'builtins.float' received for the 'nbinsx' property of histogram
#         Received value: 0.02
#
#     The 'nbinsx' property is a integer and may be specified as:
#       - An int (or float that will be cast to an int)
#         in the interval [0, 9223372036854775807]
