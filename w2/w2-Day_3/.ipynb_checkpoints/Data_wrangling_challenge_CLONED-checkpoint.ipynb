# %% [markdown]
# # Data Wrangling Challenge
# ### Pull and manipulate the API data
#
# The point of this exercise is to try data enrichment with data from external APIs. We are going to take data about car crashes in Monroe County, Indiana from 2003 to 2015 and try to figure out the weather during the accident and how many bars there are in the area. We will work with two different APIs during this challenge:
#
# - Foursquare API
# - Visual Crossing API
#
# We will try to find correlations between the severity of crash and weather/number of bars in the area. To indicate the severity of a crash, we will use column `Injury Type`.

# %% [markdown]
# ## Data
#
# The data for this exercise can be found [here](https://drive.google.com/file/d/1_KF9oIJV8cB8i3ngA4JPOLWIE_ETE6CJ/view?usp=sharing).
#
# Just run the cells below to get your data ready. Little help from us.

# %%
import pandas as pd
from pandas import json_normalize
import os
import config

# %%
data = pd.read_csv("monroe-county-crash-data2003-to-2015.csv", encoding="unicode_escape")
# ========================
# preparing data
data.dropna(subset=['Latitude', 'Longitude'], inplace=True)
# creation of variable with lon and lat together
data['ll'] = data['Latitude'].astype(str) + ',' + data['Longitude'].astype(str)
data = data[data['ll'] != '0.0,0.0']
print(data.shape)
data.head()
# Out:
# (49005, 13)
#    Master Record Number  Year  Month  Day Weekend?    Hour Collision Type  \
# 0             902363382  2015      1    5  Weekday     0.0          2-Car
# 1             902364268  2015      1    6  Weekday  1500.0          2-Car
# 2             902364412  2015      1    6  Weekend  2300.0          2-Car
# 3             902364551  2015      1    7  Weekend   900.0          2-Car
# 4             902364615  2015      1    7  Weekend  1100.0          2-Car
#
#           Injury Type                         Primary Factor  \
# 0   No injury/unknown  OTHER (DRIVER) - EXPLAIN IN NARRATIVE
# 1   No injury/unknown                  FOLLOWING TOO CLOSELY
# 2  Non-incapacitating              DISREGARD SIGNAL/REG SIGN
# 3  Non-incapacitating          FAILURE TO YIELD RIGHT OF WAY
# 4   No injury/unknown          FAILURE TO YIELD RIGHT OF WAY
#
#        Reported_Location   Latitude  Longitude                        ll
# 0             1ST & FESS  39.159207 -86.525874  39.15920668,-86.52587356
# 1          2ND & COLLEGE  39.161440 -86.534848       39.16144,-86.534848
# 2  BASSWOOD & BLOOMFIELD  39.149780 -86.568890  39.14978027,-86.56889006
# 3         GATES & JACOBS  39.165655 -86.575956    39.165655,-86.57595635
# 4                  W 3RD  39.164848 -86.579625    39.164848,-86.57962482

# %%
data.keys() # Now we need WEATHER and BARS IN AREA for that date
# Out:
# Index(['Master Record Number', 'Year', 'Month', 'Day', 'Weekend?', 'Hour',
#        'Collision Type', 'Injury Type', 'Primary Factor', 'Reported_Location',
#        'Latitude', 'Longitude', 'll'],
#       dtype='object')

# %%
# params = dict(client_id = foursquare_id
#               client_secret=foursquare_secret
#               v="20180323"
#               ll = ll
#               query="bar"
#               limit=50, radius=5000)

# return requests.get
# Out:
#                              ll
# 0      39.15920668,-86.52587356
# 1           39.16144,-86.534848
# 2      39.14978027,-86.56889006
# 3        39.165655,-86.57595635
# 4        39.164848,-86.57962482
# ...                         ...
# 53344  39.00427482,-86.58137523
# 53345      39.002752,-86.463856
# 53346  38.99232624,-86.53725171
# 53347       38.99152,-86.448784
# 53348      38.990848,-86.368864
#
# [49005 rows x 1 columns]

# %% [markdown]
# # Foursquare API
#
# Foursquare API documentation is [here](https://developer.foursquare.com/)
#
# 1. Start a foursquare application and get your keys.
# 2. For each crash, create the function **get_venues** that will pull bars in the radius of 5km around the crash
#
# #### example
# `get_venues('48.146394, 17.107969')`
#
# 3. Find a relationship (if there is any) between number of bars in the area and severity of the crash.
#
# HINTs:
# - check out python package "foursquare" (no need to send HTTP requests directly with library `requests`)
# - **categoryId** for bars and nightlife needs to be found in the [foursquare API documentation](https://developer.foursquare.com/docs/api-reference/venues/search/)

# %%
#set the keys
foursquare_id = config.FOURSQUARE_CLIENT_ID
foursquare_secret = config.FOURSQUARE_CLIENT_SECRET

# %%
lat_long = "39.16144,-86.534848"

# %%
url_venues = "https://api.foursquare.com/v2/venues/search?near=39.122352,-86.5712&client_id="+foursquare_id+"&client_secret="+foursquare_secret+"&v=20200731"

# %%
import requests as re
res = re.get(url_venues)
res
# Out:
# <Response [200]>

# %%
venues_json = res.json()
type(venues_json) # VENUES DONE
# Out:
# dict

# %%
venues_json.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
venues_json["response"].keys()
# Out:
# dict_keys(['venues', 'confident', 'geocode'])

# %%
venues = json_normalize(venues_json["response"]["venues"])
# Out:
#                           id                             name  \
# 0   569fa53c498ec3cca20ebf6b    Cook Vascular Training Center
# 1   4afdccbff964a520f92a22e3                           Kroger
# 2   59ced309a9fe123f1ca6a21e    Friendly Beasts Cider Company
# 3   5f494a60aefbc30ef2c41480                 Jeff’s Warehouse
# 4   4c796ce2566db60ce9eb440e               Furniture Exchange
# 5   4e31c4302fb6ede816e38555                           Redbox
# 6   4e8cd95755032ad219e7148f                   US Post Office
# 7   4ba1174bf964a520df9637e3                          Wendy’s
# 8   5e8fe51b8655b4000873b42e            Happy Thai Restaurant
# 9   4dc5ae96e4cd169dc653b749              The Chocolate Moose
# 10  4c26839bf3859c7487676588                     Peach Garden
# 11  512c092ce4b0ccaae56fe010                  My Thai Express
# 12  4b904659f964a520a98033e3                           Arby's
# 13  4afa0d6af964a5205d1622e3                 Grazie! Italiano
# 14  4b2050c0f964a520803024e3                   Big Red Outlet
# 15  4af38d33f964a5208eee21e3                     Malibu Grill
# 16  4aeda1b2f964a520f1cd21e3                      Uptown Cafe
# 17  593e19af7269fe61569c1dcf                          Bluetip
# 18  4e80b6808231841cb8e40cdd      United Way of Monroe County
# 19  56fd6843498eee405666ff3f                 Hopscotch Coffee
# 20  4b7efb4bf964a520140e30e3                          Rally's
# 21  4f32bfcb19836c91c7f65186                 Spectrum Studios
# 22  4b842d25f964a520ad2531e3                      Sahara Mart
# 23  4b60e357f964a520ddff29e3            Courtyard Bloomington
# 24  5e9e9d6317ca5f0007ea4b1f                 KeyMe Locksmiths
# 25  591c5ea16eda0263a3166d9e                  Kroger Pharmacy
# 26  542a3a5a498e0b0d25839f88                       Sofra Cafe
# 27  592908018d0a535029fbeb52                        iMechanic
# 28  4d1d0fd72eb1f04d1d3dd3c1  Therapeutic Massage & Bodyworks
# 29  4cc0640797bc721ef4218b67                 Hoosier CrossFit
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1632358598    False
# 1   [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...  v-1632358598    False
# 2                                                  []  v-1632358598    False
# 3   [{'id': '4bf58dd8d48988d101951735', 'name': 'T...  v-1632358598    False
# 4   [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...  v-1632358598    False
# 5   [{'id': '4bf58dd8d48988d126951735', 'name': 'V...  v-1632358598    False
# 6   [{'id': '4bf58dd8d48988d172941735', 'name': 'P...  v-1632358598    False
# 7   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1632358598    False
# 8   [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1632358598    False
# 9   [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...  v-1632358598    False
# 10  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1632358598    False
# 11  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...  v-1632358598    False
# 12  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1632358598    False
# 13  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1632358598    False
# 14  [{'id': '4bf58dd8d48988d186941735', 'name': 'L...  v-1632358598    False
# 15  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...  v-1632358598    False
# 16  [{'id': '4bf58dd8d48988d17a941735', 'name': 'C...  v-1632358598    False
# 17  [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...  v-1632358598    False
# 18  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1632358598    False
# 19  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1632358598    False
# 20  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1632358598    False
# 21  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...  v-1632358598    False
# 22  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1632358598    False
# 23  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1632358598    False
# 24  [{'id': '52f2ab2ebcbc57f1066b8b1e', 'name': 'L...  v-1632358598    False
# 25  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...  v-1632358598    False
# 26  [{'id': '4f04af1f2fb6e1c99f3db0bb', 'name': 'T...  v-1632358598    False
# 27  [{'id': '4f04afc02fb6e1c99f3db0bc', 'name': 'M...  v-1632358598    False
# 28                                                 []  v-1632358598    False
# 29  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1632358598    False
#
#     location.lat  location.lng  \
# 0      39.166258    -86.534140
# 1      39.159901    -86.535746
# 2      39.161694    -86.535866
# 3      39.162063    -86.535121
# 4      39.162097    -86.535502
# 5      39.161290    -86.534952
# 6      39.160528    -86.534063
# 7      39.161105    -86.535760
# 8      39.160348    -86.533324
# 9      39.162665    -86.533564
# 10     39.159931    -86.535561
# 11     39.160310    -86.533363
# 12     39.160007    -86.533274
# 13     39.167681    -86.533926
# 14     39.161554    -86.533483
# 15     39.166865    -86.533579
# 16     39.166434    -86.533349
# 17     39.162300    -86.535200
# 18     39.161761    -86.534532
# 19     39.161730    -86.533679
# 20     39.159545    -86.534115
# 21     39.162121    -86.535187
# 22     39.161355    -86.533177
# 23     39.163829    -86.535389
# 24     39.159900    -86.535700
# 25     39.160132    -86.535545
# 26     39.163052    -86.533767
# 27     39.161900    -86.533290
# 28     39.162292    -86.536707
# 29     39.162509    -86.535575
#
#                               location.labeledLatLngs location.cc  \
# 0   [{'label': 'display', 'lat': 39.16625761663199...          US
# 1   [{'label': 'display', 'lat': 39.1599011, 'lng'...          US
# 2   [{'label': 'display', 'lat': 39.161694, 'lng':...          US
# 3   [{'label': 'display', 'lat': 39.162063, 'lng':...          US
# 4   [{'label': 'display', 'lat': 39.16209699999999...          US
# 5   [{'label': 'display', 'lat': 39.16129, 'lng': ...          US
# 6   [{'label': 'entrance', 'lat': 39.160495, 'lng'...          US
# 7   [{'label': 'display', 'lat': 39.16110473161429...          US
# 8   [{'label': 'display', 'lat': 39.160348, 'lng':...          US
# 9   [{'label': 'display', 'lat': 39.162665, 'lng':...          US
# 10  [{'label': 'display', 'lat': 39.15993118286133...          US
# 11  [{'label': 'display', 'lat': 39.16030997333662...          US
# 12  [{'label': 'display', 'lat': 39.1600066343555,...          US
# 13  [{'label': 'display', 'lat': 39.16768145607438...          US
# 14  [{'label': 'display', 'lat': 39.16155392244062...          US
# 15  [{'label': 'display', 'lat': 39.1668649358185,...          US
# 16  [{'label': 'display', 'lat': 39.16643420713071...          US
# 17  [{'label': 'display', 'lat': 39.1623, 'lng': -...          US
# 18  [{'label': 'display', 'lat': 39.16176094003290...          US
# 19  [{'label': 'display', 'lat': 39.16173041757003...          US
# 20  [{'label': 'display', 'lat': 39.15954492925336...          US
# 21  [{'label': 'display', 'lat': 39.1621208190918,...          US
# 22  [{'label': 'display', 'lat': 39.16135483028275...          US
# 23  [{'label': 'display', 'lat': 39.1638289, 'lng'...          US
# 24  [{'label': 'display', 'lat': 39.1599, 'lng': -...          US
# 25  [{'label': 'display', 'lat': 39.1601317, 'lng'...          US
# 26  [{'label': 'display', 'lat': 39.16305248112930...          US
# 27  [{'label': 'display', 'lat': 39.1619, 'lng': -...          US
# 28  [{'label': 'display', 'lat': 39.16229226395851...          US
# 29  [{'label': 'display', 'lat': 39.162509, 'lng':...          US
#
#    location.city  ...      location.crossStreet location.postalCode  \
# 0    Bloomington  ...                       NaN                 NaN
# 1    Bloomington  ...                 at W. 2nd               47403
# 2    Bloomington  ...            B-line and 2nd               47403
# 3    Bloomington  ...                       NaN               47403
# 4    Bloomington  ...                       NaN               47404
# 5    Bloomington  ...                       NaN               47403
# 6    Bloomington  ...           1st & Walnut St               47401
# 7    Bloomington  ...                       NaN               47403
# 8    Bloomington  ...                       NaN               47401
# 9    Bloomington  ...                       NaN               47401
# 10   Bloomington  ...                    at 1st               47403
# 11   Bloomington  ...                       NaN               47401
# 12   Bloomington  ...                       NaN               47401
# 13   Bloomington  ...  Walnut & West 6th Street               47404
# 14   Bloomington  ...                 at 2nd St               47401
# 15   Bloomington  ...              Kirkwood Ave               47404
# 16   Bloomington  ...                       NaN               47408
# 17   Bloomington  ...                       NaN               47403
# 18   Bloomington  ...                       NaN                 NaN
# 19   Bloomington  ...                       NaN                 NaN
# 20   Bloomington  ...                   1st St.               47401
# 21   Bloomington  ...                       NaN               47403
# 22   Bloomington  ...                       NaN               47401
# 23   Bloomington  ...                       NaN               47403
# 24   Bloomington  ...                       NaN               47403
# 25   Bloomington  ...                       NaN               47403
# 26   Bloomington  ...                       NaN               47401
# 27   Bloomington  ...                       NaN               47401
# 28           NaN  ...                       NaN                 NaN
# 29   Bloomington  ...                2nd Street               47403
#
#    location.neighborhood venuePage.id delivery.id  \
# 0                    NaN          NaN         NaN
# 1                    NaN          NaN         NaN
# 2   Downtown Bloomington    479158422         NaN
# 3                    NaN          NaN         NaN
# 4                    NaN     36587240         NaN
# 5                    NaN          NaN         NaN
# 6                    NaN          NaN         NaN
# 7                    NaN          NaN     1684878
# 8                    NaN          NaN     2100167
# 9                    NaN          NaN      797018
# 10                   NaN          NaN      260643
# 11                   NaN     50205735         NaN
# 12                   NaN          NaN         NaN
# 13                   NaN     32899173         NaN
# 14                   NaN          NaN         NaN
# 15                   NaN     59602343         NaN
# 16                   NaN    530285805         NaN
# 17                   NaN          NaN         NaN
# 18                   NaN          NaN         NaN
# 19                   NaN          NaN         NaN
# 20                   NaN          NaN     2540226
# 21                   NaN          NaN         NaN
# 22                   NaN          NaN         NaN
# 23                   NaN     74982147         NaN
# 24                   NaN          NaN         NaN
# 25                   NaN          NaN         NaN
# 26                   NaN     98212400         NaN
# 27                   NaN          NaN         NaN
# 28                   NaN          NaN         NaN
# 29                   NaN          NaN         NaN
#
#                                          delivery.url delivery.provider.name  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7   https://www.grubhub.com/restaurant/wendys-221-...                grubhub
# 8   https://www.grubhub.com/restaurant/happy-thai-...                grubhub
# 9   https://www.grubhub.com/restaurant/the-chocola...                grubhub
# 10  https://www.grubhub.com/restaurant/peach-garde...                grubhub
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20  https://www.grubhub.com/restaurant/rallys-550-...                grubhub
# 21                                                NaN                    NaN
# 22                                                NaN                    NaN
# 23                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25                                                NaN                    NaN
# 26                                                NaN                    NaN
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
# 29                                                NaN                    NaN
#
#                delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# 5                                        NaN                          NaN
# 6                                        NaN                          NaN
# 7   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 8   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 9   https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 10  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 11                                       NaN                          NaN
# 12                                       NaN                          NaN
# 13                                       NaN                          NaN
# 14                                       NaN                          NaN
# 15                                       NaN                          NaN
# 16                                       NaN                          NaN
# 17                                       NaN                          NaN
# 18                                       NaN                          NaN
# 19                                       NaN                          NaN
# 20  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 21                                       NaN                          NaN
# 22                                       NaN                          NaN
# 23                                       NaN                          NaN
# 24                                       NaN                          NaN
# 25                                       NaN                          NaN
# 26                                       NaN                          NaN
# 27                                       NaN                          NaN
# 28                                       NaN                          NaN
# 29                                       NaN                          NaN
#
#                 delivery.provider.icon.name
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7   /delivery_provider_grubhub_20180129.png
# 8   /delivery_provider_grubhub_20180129.png
# 9   /delivery_provider_grubhub_20180129.png
# 10  /delivery_provider_grubhub_20180129.png
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20  /delivery_provider_grubhub_20180129.png
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
#
# [30 rows x 24 columns]

# %%
# need to use ll, this median ll doesn't work. Need to correlate

# %% [markdown]
# # Visual Crossing API
#
# Virtual Crossing API documentation is [here](https://www.visualcrossing.com/resources/documentation/)
#
# 1. Sign up for FREE api key if you haven't done that before.
# 2. For each crush, get the weather for the location and date.
# 3. Find a relationship between the weather and severity of the crash.
#
# Hints:
#
# * randomly sample only 250 or so (due to API limits), or pull weather only for smaller sample of crashes
# * for sending HTTP requests check out "requests" library [here](http://docs.python-requests.org/en/master/)

# %%
import requests
import time
api_key = os.environ[]
