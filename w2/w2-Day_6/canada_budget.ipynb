# %%
import pandas as pd
import numpy as np

# %%
canada = pd.read_csv("canada_databaseLoadingData.csv")

# %%
canada.head(2)
# Out:
#   REF_DATE     GEO           DGUID                  Seasonal adjustment  \
# 0  2020-04  Canada  2016A000011124  Seasonally adjusted at annual rates
# 1  2020-07  Canada  2016A000011124  Seasonally adjusted at annual rates
#
#   Levels of government                    Estimates      UOM  UOM_ID  \
# 0  General governments  General governments revenue  Dollars      81
# 1  General governments  General governments revenue  Dollars      81
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE   VALUE  STATUS  SYMBOL  \
# 0      millions          6  v62425528    1.1.1.1  878744     NaN     NaN
# 1      millions          6  v62425528    1.1.1.1  935804     NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0

# %%
import plotly.express as px
fig = px.bar(canada, x=canada["REF_DATE"], y=canada["VALUE"])
fig.show()
# Out:
# <div>                            <div id="2b4dc849-be96-4e98-bffd-ef06c6a4aa50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b4dc849-be96-4e98-bffd-ef06c6a4aa50")) {                    Plotly.newPlot(                        "2b4dc849-be96-4e98-bffd-ef06c6a4aa50",                        [{"alignmentgroup":"True","hovertemplate":"REF_DATE=%{x}<br>VALUE=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["2020-04","2020-07","2020-10","2021-01","2021-04","2020-04","2020-07","2020-10","2021-01","2021-04","2020-04","2020-07","2020-10","2021-01","2021-04","2020-04","2020-07","2020-10","2021-01","2021-04","2020-04
# ...

# %%
import plotly.express as px
fig = px.pie(canada, values=canada["VALUE"], names=canada["Estimates"], title='Canadian Truderp Budget (by 1,000,000)')
fig.show()
# Out:
# <div>                            <div id="1d13af48-5942-46f5-9fbe-0d2fa5b7f744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d13af48-5942-46f5-9fbe-0d2fa5b7f744")) {                    Plotly.newPlot(                        "1d13af48-5942-46f5-9fbe-0d2fa5b7f744",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Estimates=%{label}<br>VALUE=%{value}<extra></extra>","labels":["General governments revenue","General governments revenue","General governments revenue","General governments revenue","General governments revenue","Taxes on incomes","Taxes on incomes","Taxes on incomes","Taxes on incomes","Taxes on incomes","From households","From households","From households","From households","From households","Income taxe
# ...
