# %% [markdown]
# ## Central Limit Theorem Exercise

# %%
import pandas as pd
import numpy as np
# package with hypothesis tests
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
#
uniform = np.random.rand(10000) # 
normal = np.random.randn(10000) # guassian?

fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
ax1.hist(uniform, 20)
ax1.set_title('Uniform data')
ax2.hist(normal, 20)
ax2.set_title('Normal data')
fig.tight_layout()
fig.show();
# Out:
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_7937/1035564930.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show();

# %% [markdown]
# ### CLT - simulation

# %% [markdown]
# ### How many samples do we need to take, so that the distribution of means for these samples will pass the shapiro-wilk test for normality if the population is from a Uniform or a Normal distribution?
#
# + Assume the population has 10,000 observation.
# + Assume sample size is always 50.
#
# We will be suprised to see how fast the test passes for both distributions.

# %%
from scipy.stats import shapiro # SHAPIRO
normal = np.random.randn(1000)
stat, p = shapiro(normal)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(normal, 20)
ax1.set_title('normal/Guassian data')
fig.tight_layout()
fig.show();
# Out:
# stat=0.999, p=0.661
# Probably Gaussian
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_19707/333571591.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show();

# %%
from scipy.stats import shapiro # SHAPIRO
uniform = np.random.rand(10000)
stat, p = shapiro(uniform)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(uniform, 200)
ax1.set_title('Uniform/Non-Guassian data')
fig.tight_layout()
fig.show();
# Out:
# /Users/louisrossi/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_19707/1644657832.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show();
# stat=0.955, p=0.000
# Probably not Gaussian

# %%
from scipy.stats import normaltest # DAGOSTINO TEST - GUASSIAN???
normal = np.random.randn(1000)
stat, p = normaltest(normal)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(normal, 20)
ax1.set_title('normal/Guassian data')
fig.tight_layout()
fig.show();
# Out:
# stat=4.857, p=0.088
# Probably Gaussian
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_5104/2928312421.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show();

# %%
from scipy.stats import normaltest # DAGOSTINO TEST - GUASSIAN???
uniform = np.random.rand(1000)
stat, p = normaltest(uniform)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
	print('Probably Gaussian')
else:
	print('Probably not Gaussian')
fig = plt.figure(figsize=(14,5))
ax1 = fig.add_subplot(1,2,1)
ax1.hist(uniform, 20)
ax1.set_title('uniform/non-Guassian data')
fig.tight_layout()
fig.show();
# Out:
# stat=1397.358, p=0.000
# Probably not Gaussian
# /var/folders/wg/4yj17hrn3q9g_27l8zsxxy5m0000gn/T/ipykernel_19707/1839156921.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show();
